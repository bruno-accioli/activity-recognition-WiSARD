# %%
import pickle

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
with open('results/model1_gs_results.pickle', 'rb') as file:
    gs_model1 = pickle.load(file)
    
with open('results/model2_gs_results.pickle', 'rb') as file:
    gs_model2 = pickle.load(file)

# %%
gs_model1 = gs_model1.sort_values(['param_thermometer__n_bits', 'param_wisard__address_size']).reset_index()
gs_model2 = gs_model2.sort_values(['param_thermometer__n_bits', 'param_wisard__address_size']).reset_index()

# %% [markdown]
# Calculating the percentage of times model 2 got better results than model 1.

# %%
(gs_model2['mean_test_score'] > gs_model1['mean_test_score']).mean()
# Out:
# 1.0

# %%
accuracy_increase = ((gs_model2['mean_test_score'] - gs_model1['mean_test_score']) /gs_model1['mean_test_score']) * 100
ax = sns.lineplot(x=gs_model1['param_thermometer__n_bits'], y=accuracy_increase)
ax.set_title('Aumento percentual da acurácia média', size=14)
ax.set_ylabel('Aumento de acurácia (%)', size=12)
ax.set_xlabel('Número de bits do termômetro', size=12)
ax.set_xticks([40, 50, 60])
ax.set_ylim(0, 6)
sns.despine()

# %%
accuracy_increase = ((gs_model2['mean_test_score'] - gs_model1['mean_test_score']) /gs_model1['mean_test_score']) * 100
ax = sns.lineplot(x=gs_model1['param_wisard__address_size'], y=accuracy_increase)
ax.set_title('Aumento percentual da acurácia média', size=14)
ax.set_ylabel('Aumento de acurácia (%)', size=12)
ax.set_xlabel('Tamanho do endereço (WiSARD)', size=12)
ax.set_ylim(0, 7)
sns.despine()

# %%
((gs_model2['mean_fit_time'])/5 - (gs_model1['mean_fit_time'])/5).plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
gs_model1
# Out:
#     level_0  index  mean_fit_time  std_fit_time  mean_score_time  \
# 0         0     16      24.307752      1.083416         9.742637
# 1         1     15      17.820736      3.682697         8.816704
# 2         2     14      17.439127      1.076912         9.430070
# 3         3      7      23.488148      5.909041         9.662979
# 4         4      4      29.698171      5.710025         8.546227
# 5         5      0      20.328891      0.242954         7.312314
# 6         6     17      43.571204      4.051173        13.746344
# 7         7     13      36.724894      2.164612        12.053815
# 8         8     11      32.550133      2.419600        10.892707
# 9         9      8      29.494567      1.445076         9.974584
# 10       10      6      31.109782      2.099701         9.262461
# 11       11      5      35.597230      1.318281         9.352219
# 12       12     12      48.168515      4.871919        17.905377
# ...

# %%
# Out:
#     level_0  index  mean_fit_time  std_fit_time  mean_score_time  \
# 0         0      8      24.910981      1.040104        10.754639
# 1         1      5      19.927462      1.712573         9.382508
# 2         2     10      16.961186      2.138364         8.167022
# 3         3     12      15.470603      0.709333         8.010079
# 4         4     16      16.437246      1.469829         8.301901
# 5         5     17      16.858525      0.477844         7.472708
# 6         6     14      33.127447      2.223267        13.781516
# 7         7      2      26.868439      5.037538        14.267180
# 8         8      1      26.163297      3.746190        12.788917
# 9         9      7      29.978571      7.016742        10.181193
# 10       10     15      20.109871      2.438342         8.923648
# 11       11     11      21.592130      4.508998         9.561219
# 12       12      0      36.665671      3.756936        18.875014
# ...
